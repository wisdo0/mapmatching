# %%
# -*- coding: utf-8 -*-
# @Author  : zhang35
# @Time    : 2020/09/16 18:00
# @Function: extract stay points from a GPS log file (implementation of algorithm in [1])

# References:
# [1] Q. Li, Y. Zheng, X. Xie, Y. Chen, W. Liu, and W.-Y. Ma, "Mining user similarity based on location history", in Proceedings of the 16th ACM SIGSPATIAL international conference on Advances in geographic information systems, New York, NY, USA, 2008, pp. 34:1--34:10.

# Test data could be downloaded from: https://www.microsoft.com/en-us/download/confirmation.aspx?id=52367

import time
import os
import sys
from math import radians, cos, sin, asin, sqrt
import folium
import webbrowser

import pandas as pd

time_format = '%Y-%m-%d,%H:%M:%S'


# structure of point
class Point:
    def __init__(self, latitude, longitude, dateTime, arriveTime, leaveTime):
        self.latitude = latitude
        self.longitude = longitude
        self.dateTime = dateTime
        self.arriveTime = arriveTime
        self.leaveTime = leaveTime


# calculate distance between two points from their coordinate
def getDistanceOfPoints(pi, pj):
    lat1, lon1, lat2, lon2 = list(map(radians, [float(pi.latitude), float(pi.longitude),
                                                float(pj.latitude), float(pj.longitude)]))
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * asin(sqrt(a))
    m = 6371000 * c
    return m


# calculate time interval between two points
def getTimeIntervalOfPoints(pi, pj):
    t_i = time.mktime(time.strptime(pi.dateTime, time_format))
    t_j = time.mktime(time.strptime(pj.dateTime, time_format))
    return t_j - t_i


# compute mean coordinates of a group of points
def computMeanCoord(gpsPoints):
    lat = 0.0
    lon = 0.0
    for point in gpsPoints:
        lat += float(point.latitude)
        lon += float(point.longitude)
    return (lat / len(gpsPoints), lon / len(gpsPoints))


# extract stay points from a GPS log file
# input:
#        file: the name of a GPS log file
#        distThres: distance threshold
#        timeThres: time span threshold
# default values of distThres and timeThres are 200 m and 30 min respectively, according to [1]
def stayPointExtraction(points, distThres=200, timeThres=30 * 60):
    stayPointList = []
    stayPointCenterList = []
    pointNum = len(points)
    i = 0
    while i < pointNum:
        j = i + 1
        while j < pointNum:
            if getDistanceOfPoints(points[i], points[j]) > distThres:
                # points[j] has gone out of bound thus it should not be counted in the stay points.
                if getTimeIntervalOfPoints(points[i], points[j - 1]) > timeThres:
                    latitude, longitude = computMeanCoord(points[i:j])
                    arriveTime = time.mktime(time.strptime(points[i].dateTime, time_format))
                    leaveTime = time.mktime(time.strptime(points[j - 1].dateTime, time_format))
                    dateTime = time.strftime(time_format, time.localtime(arriveTime)), time.strftime(time_format,
                                                                                                     time.localtime(
                                                                                                         leaveTime))
                    stayPointCenterList.append(Point(latitude, longitude, dateTime, arriveTime, leaveTime))
                    stayPointList.extend(points[i:j])
                break
            j += 1
        i = j
    return stayPointCenterList, stayPointList


# parse lines into points
def parseGeoTxt(lines):
    points = []
    for line in lines:
        field_pointi = line.rstrip().split(',')
        latitude = float(field_pointi[0])
        longitude = float(field_pointi[1])
        dateTime = field_pointi[-2] + ',' + field_pointi[-1]
        points.append(Point(latitude, longitude, dateTime, 0, 0))
    return points


# add points into mapDots (type: folium.map.FeatureGroup())
def addPoints(mapDots, points, color):
    for p in points:
        mapDots.add_child(folium.CircleMarker(
            [p.latitude, p.longitude],
            radius=4,
            tooltip=p.dateTime,
            color=color,
        ))


def main():
    m = folium.Map(location=[40.007814, 116.319764])
    tooltip = "hello"
    mapDots = folium.map.FeatureGroup()

    for dirname, dirnames, filenames in os.walk(sys.path[0] + '/Data'):
        filenum = len(filenames)
        print(filenum, "files found")
        count = 0
        for filename in filenames:
            if filename.endswith('plt'):
                gpsfile = os.path.join(dirname, filename)
                print("processing:", gpsfile)
                # log = open(gpsfile, 'r')
                # lines = log.readlines()[6:] # first 6 lines are useless
                # points = parseGeoTxt(lines)
                points
                stayPointCenter, stayPoint = stayPointExtraction(points)
                addPoints(mapDots, points, 'yellow')

                if len(stayPointCenter) > 0:
                    # add pionts to a group to be shown on map
                    addPoints(mapDots, stayPoint, 'blue')
                    addPoints(mapDots, stayPointCenter, 'red')

                    # writen into file ./StayPoint/*.plt
                    spfile = gpsfile.replace('Data', 'StayPoint').replace('.plt', '_basic.plt')
                    if not os.path.exists(os.path.dirname(spfile)):
                        os.makedirs(os.path.dirname(spfile))
                    spfile_handle = open(spfile, 'w+')
                    print('Extracted stay points:\nlaltitude\tlongitude\tarriving time\tleaving time',
                          file=spfile_handle)
                    for sp in stayPointCenter:
                        print(sp.latitude, sp.longitude, time.strftime(time_format, time.localtime(sp.arriveTime)),
                              time.strftime(time_format, time.localtime(sp.leaveTime)), file=spfile_handle)
                    spfile_handle.close()

                    print("writen into:", spfile)
                    count += 1
                else:
                    print(gpsfile, "has no stay point")
        print(count, "out of", filenum, "files contain stay points")

    # show stay points on map
    m.add_child(mapDots)
    m.save(sys.path[0] + "/index1.html")
    webbrowser.open(sys.path[0] + "/index1.html")


if __name__ == '__main__':
    main()

# %%
# -*- coding: utf-8 -*-
# @Author  : zhang35
# @Time    : 2020/09/16 18:00
# @Function: extract stay points from a GPS log file (implementation of algorithm in [2])

# References:
# [1] Q. Li, Y. Zheng, X. Xie, Y. Chen, W. Liu, and W.-Y. Ma, "Mining user similarity based on location history", in Proceedings of the 16th ACM SIGSPATIAL international conference on Advances in geographic information systems, New York, NY, USA, 2008, pp. 34:1--34:10.
# [2] Jing Yuan, Yu Zheng, Liuhang Zhang, XIng Xie, and Guangzhong Sun. 2011. Where to find my next passenger. In Proceedings of the 13th international conference on Ubiquitous computing (UbiComp '11). Association for Computing Machinery, New York, NY, USA, 109–118.

# test data could be downloaded from: https://www.microsoft.com/en-us/download/confirmation.aspx?id=52367

import time
import os
import sys
from math import radians, cos, sin, asin, sqrt
import transbigdata
# import folium
# import webbrowser
import numpy as np
import pandas as pd

time_format = '%Y-%m-%d %H:%M:%S'


# structure of point
class Point:
    def __init__(self, latitude, longitude, dateTime, arriveTime, leaveTime):
        self.latitude = latitude
        self.longitude = longitude
        self.dateTime = dateTime
        self.arriveTime = arriveTime
        self.leaveTime = leaveTime


# calculate distance between two points from their coordinate
def getDistanceOfPoints(pi, pj):
    lat1, lon1, lat2, lon2 = list(map(radians, [float(pi.latitude), float(pi.longitude),
                                                float(pj.latitude), float(pj.longitude)]))
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * asin(sqrt(a))
    m = 6371000 * c
    return m


# calculate time interval between two points
def getTimeIntervalOfPoints(pi, pj):
    t_i = time.mktime(time.strptime(pi.dateTime, time_format))
    t_j = time.mktime(time.strptime(pj.dateTime, time_format))
    return t_j - t_i


# compute mean coordinates of a group of points
def computMeanCoord(gpsPoints):
    lat = 0.0
    lon = 0.0
    for point in gpsPoints:
        lat += float(point.latitude)
        lon += float(point.longitude)
    return (lat / len(gpsPoints), lon / len(gpsPoints))


# extract stay points from a GPS log file
# input:
#        file: the name of a GPS log file
#        distThres: distance threshold
#        timeThres: time span threshold
# default values of distThres and timeThres are 200 m and 30 min respectively, according to [1]
def stayPointExtraction(points, distThres=200, timeThres=30 * 60):
    stayPointCenterList = []
    stayPointList = []
    pointNum = len(points)
    i = 0
    while i < pointNum - 1:
        # j: index of the last point within distTres
        j = i + 1
        flag = False
        while j < pointNum:
            if getDistanceOfPoints(points[i], points[j]) < distThres:
                j += 1
            else:
                break

        j -= 1
        # at least one point found within distThres
        if j > i:
            # candidate cluster found
            if getTimeIntervalOfPoints(points[i], points[j]) > timeThres:
                nexti = i + 1
                j += 1
                while j < pointNum:
                    if getDistanceOfPoints(points[nexti], points[j]) < distThres and getTimeIntervalOfPoints(
                        points[nexti], points[j]) > timeThres:
                        nexti += 1
                        j += 1
                    else:
                        break
                j -= 1
                # latitude, longitude = computMeanCoord(points[i: j + 1])
                latitude, longitude =points[j].latitude,points[j].longitude
                arriveTime = time.mktime(time.strptime(points[i].dateTime, time_format))
                leaveTime = time.mktime(time.strptime(points[j].dateTime, time_format))
                dateTime = time.strftime(time_format, time.localtime(arriveTime)), time.strftime(time_format,
                                                                                                 time.localtime(
                                                                                                     leaveTime))
                stayPointCenterList.append(Point(latitude, longitude, dateTime, arriveTime, leaveTime))
                stayPointList.extend(points[i: j + 1])
        i = j + 1
    return stayPointCenterList, stayPointList


# add points into mapDots (type: folium.map.FeatureGroup())
def addPoints(mapDots, points, color):
    for p in points:
        mapDots.add_child(folium.CircleMarker(
            [p.latitude, p.longitude],
            radius=4,
            tooltip=p.dateTime,
            color=color
        ))


# parse lines into points
def parseGeoTxt(lines):
    points = []
    for line in lines:
        field_pointi = line.rstrip().split(',')
        latitude = float(field_pointi[0])
        longitude = float(field_pointi[1])
        dateTime = field_pointi[-2] + ',' + field_pointi[-1]
        points.append(Point(latitude, longitude, dateTime, 0, 0))
    return points


def parsegeo(lines):
    points = []
    # lines['arriveTime'] = 0
    # lines['leaveTime'] = 0
    for each in lines.index:
        points.append(Point(lines.loc[each,'latitude'], lines.loc[each,'longitude'], lines.loc[each,'timestamp'], 0, 0))
    return points


def main():
    m = folium.Map(location=[40.007814, 116.319764])
    mapDots = folium.map.FeatureGroup()

    count = 0
    for dirname, dirnames, filenames in os.walk(sys.path[0] + '/Data'):
        filenum = len(filenames)
        print(filenum, "files found")
        for filename in filenames:
            if filename.endswith('plt'):
                gpsfile = os.path.join(dirname, filename)
                print("processing:", gpsfile)
                log = open(gpsfile, 'r')
                lines = log.readlines()[6:]  # first 6 lines are useless
                points = parseGeoTxt(lines)
                stayPointCenter, stayPoint = stayPointExtraction(points)
                addPoints(mapDots, points, "yellow")

                if len(stayPointCenter) > 0:
                    # add pionts to a group to be shown on map
                    addPoints(mapDots, stayPoint, "blue")
                    addPoints(mapDots, stayPointCenter, "red")

                    # writen into file ./StayPoint/*.plt
                    spfile = gpsfile.replace('Data', 'StayPoint').replace('.plt', '_density.plt')
                    if not os.path.exists(os.path.dirname(spfile)):
                        os.makedirs(os.path.dirname(spfile))
                    spfile_handle = open(spfile, 'w+')
                    print('Extracted stay points:\nlaltitude\tlongitude\tarriving time\tleaving time',
                          file=spfile_handle)
                    for sp in stayPointCenter:
                        print(sp.latitude, sp.longitude, time.strftime(time_format, time.localtime(sp.arriveTime)),
                              time.strftime(time_format, time.localtime(sp.leaveTime)), file=spfile_handle)
                    spfile_handle.close()

                    print("writen into:", spfile)
                    count += 1
                else:
                    print(gpsfile, "has no stay point")
        print(count, "out of", filenum, "files contain stay points")

    # show stay points on map
    m.add_child(mapDots)
    m.save(sys.path[0] + "/index2.html")
    webbrowser.open(sys.path[0] + "/index2.html")


if __name__ == '__main__':
    # main()
    df = pd.read_csv('rome_final.csv', usecols=["tag_new", "latitude", "longitude", "timestamp"],float_precision='high')
    tag = df["tag_new"].unique()
    count = 0
    for each in tag:
        lines=df[df['tag_new'] == each][["latitude", "longitude", "timestamp"]].copy().reset_index(drop=True)
        points = parsegeo(lines)
        stayPointlast, stayPoint = stayPointExtraction(points,distThres=50, timeThres=7 * 60)
        if len(stayPointlast) > 0:
            nm=str(each)+'.csv'
            spfile=os.path.join('.\\stayPointlast',nm)
            if not os.path.exists('.\\stayPointlast'):
                os.makedirs('.\\stayPointlast')
            spfile_handle = open(spfile, 'w+')
            print('laltitude,longitude,arriving time,leaving time',file=spfile_handle)
            for sp in stayPointlast:
                print(sp.latitude, sp.longitude, time.strftime(time_format, time.localtime(sp.arriveTime)),
                      time.strftime(time_format, time.localtime(sp.leaveTime)), file=spfile_handle,sep=',')
            spfile_handle.close()
            count += 1
        else:
            print('traj',str(each), "has no stay point")
    print(count,  "files contain stay points")
# Out:
# traj 15 has no stay point
# traj 20 has no stay point
# traj 21 has no stay point
# traj 26 has no stay point
# traj 28 has no stay point
# traj 32 has no stay point
# traj 66 has no stay point
# traj 124 has no stay point
# traj 164 has no stay point
# traj 197 has no stay point
# traj 206 has no stay point
# traj 208 has no stay point
# traj 213 has no stay point
# traj 216 has no stay point
# traj 221 has no stay point
# traj 226 has no stay point
# traj 227 has no stay point
# traj 232 has no stay point
# traj 239 has no stay point
# traj 243 has no stay point
# traj 245 has no stay point
# traj 253 has no stay point
# traj 274 has no stay point
# traj 280 has no stay point
# traj 323 has no stay point
# traj 343 has no stay point
# traj 362 has no stay point
# traj 413 has no stay point
# traj 417 has no stay point
# traj 453 has no stay point
# traj 457 has no stay point
# traj 459 has no stay point
# traj 462 has no stay point
# traj 464 has no stay point
# traj 465 has no stay point
# traj 467 has no stay point
# traj 483 has no stay point
# traj 498 has no stay point
# traj 546 has no stay point
# traj 548 has no stay point
# traj 576 has no stay point
# traj 586 has no stay point
# traj 625 has no stay point
# traj 688 has no stay point
# traj 690 has no stay point
# traj 692 has no stay point
# traj 694 has no stay point
# traj 701 has no stay point
# traj 702 has no stay point
# traj 705 has no stay point
# traj 714 has no stay point
# traj 716 has no stay point
# traj 722 has no stay point
# traj 731 has no stay point
# traj 787 has no stay point
# traj 799 has no stay point
# traj 816 has no stay point
# traj 821 has no stay point
# traj 830 has no stay point
# traj 834 has no stay point
# traj 836 has no stay point
# traj 838 has no stay point
# traj 843 has no stay point
# traj 880 has no stay point
# traj 924 has no stay point
# traj 928 has no stay point
# traj 932 has no stay point
# traj 941 has no stay point
# traj 943 has no stay point
# traj 950 has no stay point
# traj 952 has no stay point
# traj 954 has no stay point
# traj 983 has no stay point
# traj 988 has no stay point
# traj 990 has no stay point
# traj 992 has no stay point
# traj 996 has no stay point
# traj 1000 has no stay point
# traj 1006 has no stay point
# traj 1010 has no stay point
# traj 1041 has no stay point
# traj 1052 has no stay point
# traj 1059 has no stay point
# traj 1064 has no stay point
# traj 1067 has no stay point
# traj 1074 has no stay point
# traj 1076 has no stay point
# traj 1083 has no stay point
# traj 1084 has no stay point
# traj 1086 has no stay point
# traj 1092 has no stay point
# traj 1095 has no stay point
# traj 1099 has no stay point
# traj 1105 has no stay point
# traj 1109 has no stay point
# traj 1142 has no stay point
# traj 1143 has no stay point
# traj 1155 has no stay point
# traj 1163 has no stay point
# traj 1165 has no stay point
# traj 1170 has no stay point
# traj 1172 has no stay point
# traj 1173 has no stay point
# traj 1175 has no stay point
# traj 1192 has no stay point
# traj 1196 has no stay point
# traj 1198 has no stay point
# traj 1199 has no stay point
# traj 1205 has no stay point
# traj 1212 has no stay point
# traj 1214 has no stay point
# traj 1216 has no stay point
# traj 1218 has no stay point
# traj 1221 has no stay point
# traj 1226 has no stay point
# traj 1239 has no stay point
# traj 1240 has no stay point
# traj 1256 has no stay point
# traj 1260 has no stay point
# traj 1274 has no stay point
# traj 1276 has no stay point
# traj 1281 has no stay point
# traj 1287 has no stay point
# traj 1291 has no stay point
# traj 1302 has no stay point
# traj 1332 has no stay point
# traj 1334 has no stay point
# traj 1337 has no stay point
# traj 1340 has no stay point
# traj 1350 has no stay point
# traj 1357 has no stay point
# traj 1362 has no stay point
# traj 1370 has no stay point
# traj 1373 has no stay point
# traj 1381 has no stay point
# traj 1385 has no stay point
# traj 1388 has no stay point
# traj 1390 has no stay point
# traj 1391 has no stay point
# traj 1417 has no stay point
# traj 1420 has no stay point
# traj 1424 has no stay point
# traj 1426 has no stay point
# traj 1430 has no stay point
# traj 1439 has no stay point
# traj 1454 has no stay point
# traj 1469 has no stay point
# traj 1533 has no stay point
# traj 1557 has no stay point
# traj 1565 has no stay point
# traj 1587 has no stay point
# traj 1608 has no stay point
# traj 1613 has no stay point
# traj 1619 has no stay point
# traj 1632 has no stay point
# traj 1647 has no stay point
# traj 1664 has no stay point
# traj 1686 has no stay point
# traj 1688 has no stay point
# traj 1695 has no stay point
# traj 1699 has no stay point
# traj 1701 has no stay point
# traj 1717 has no stay point
# traj 1731 has no stay point
# traj 1733 has no stay point
# traj 1735 has no stay point
# traj 1738 has no stay point
# traj 1745 has no stay point
# traj 1749 has no stay point
# traj 1750 has no stay point
# traj 1751 has no stay point
# traj 1757 has no stay point
# traj 1761 has no stay point
# traj 1773 has no stay point
# traj 1785 has no stay point
# traj 1787 has no stay point
# traj 1826 has no stay point
# traj 1827 has no stay point
# traj 1836 has no stay point
# traj 1848 has no stay point
# traj 1859 has no stay point
# traj 1870 has no stay point
# traj 1872 has no stay point
# traj 1885 has no stay point
# traj 1887 has no stay point
# traj 1899 has no stay point
# traj 1900 has no stay point
# traj 1931 has no stay point
# traj 1970 has no stay point
# traj 1976 has no stay point
# traj 1983 has no stay point
# traj 1987 has no stay point
# traj 2000 has no stay point
# traj 2032 has no stay point
# traj 2040 has no stay point
# traj 2050 has no stay point
# traj 2061 has no stay point
# traj 2080 has no stay point
# traj 2094 has no stay point
# traj 2101 has no stay point
# traj 2123 has no stay point
# traj 2130 has no stay point
# traj 2169 has no stay point
# traj 2171 has no stay point
# traj 2177 has no stay point
# traj 2188 has no stay point
# traj 2236 has no stay point
# traj 2240 has no stay point
# traj 2250 has no stay point
# traj 2322 has no stay point
# traj 2323 has no stay point
# traj 2326 has no stay point
# traj 2333 has no stay point
# traj 2398 has no stay point
# traj 2417 has no stay point
# traj 2424 has no stay point
# traj 2425 has no stay point
# traj 2426 has no stay point
# traj 2428 has no stay point
# traj 2450 has no stay point
# traj 2466 has no stay point
# traj 2476 has no stay point
# traj 2479 has no stay point
# traj 2486 has no stay point
# traj 2504 has no stay point
# traj 2529 has no stay point
# traj 2561 has no stay point
# traj 2595 has no stay point
# traj 2616 has no stay point
# traj 2649 has no stay point
# traj 2651 has no stay point
# traj 2654 has no stay point
# traj 2662 has no stay point
# traj 2665 has no stay point
# traj 2689 has no stay point
# traj 2710 has no stay point
# traj 2741 has no stay point
# traj 2746 has no stay point
# traj 2773 has no stay point
# traj 2782 has no stay point
# traj 2808 has no stay point
# traj 2809 has no stay point
# traj 2816 has no stay point
# traj 2822 has no stay point
# traj 2823 has no stay point
# traj 2828 has no stay point
# traj 2829 has no stay point
# traj 2831 has no stay point
# traj 2834 has no stay point
# traj 2835 has no stay point
# traj 2839 has no stay point
# traj 2840 has no stay point
# traj 2845 has no stay point
# traj 2848 has no stay point
# traj 2849 has no stay point
# traj 2851 has no stay point
# traj 2859 has no stay point
# traj 2862 has no stay point
# traj 2872 has no stay point
# traj 2882 has no stay point
# traj 2928 has no stay point
# traj 2939 has no stay point
# traj 2940 has no stay point
# traj 2942 has no stay point
# traj 2952 has no stay point
# traj 2972 has no stay point
# traj 3015 has no stay point
# traj 3019 has no stay point
# traj 3036 has no stay point
# traj 3100 has no stay point
# traj 3104 has no stay point
# traj 3113 has no stay point
# traj 3133 has no stay point
# traj 3154 has no stay point
# traj 3180 has no stay point
# traj 3203 has no stay point
# traj 3219 has no stay point
# traj 3227 has no stay point
# traj 3236 has no stay point
# traj 3252 has no stay point
# traj 3269 has no stay point
# traj 3298 has no stay point
# traj 3324 has no stay point
# traj 3333 has no stay point
# traj 3351 has no stay point
# traj 3355 has no stay point
# traj 3360 has no stay point
# traj 3361 has no stay point
# traj 3370 has no stay point
# traj 3373 has no stay point
# traj 3375 has no stay point
# traj 3379 has no stay point
# traj 3380 has no stay point
# traj 3394 has no stay point
# traj 3411 has no stay point
# traj 3412 has no stay point
# traj 3425 has no stay point
# traj 3428 has no stay point
# traj 3435 has no stay point
# traj 3437 has no stay point
# traj 3440 has no stay point
# traj 3442 has no stay point
# traj 3444 has no stay point
# traj 3446 has no stay point
# traj 3448 has no stay point
# traj 3450 has no stay point
# traj 3452 has no stay point
# traj 3454 has no stay point
# traj 3456 has no stay point
# traj 3458 has no stay point
# traj 3461 has no stay point
# traj 3464 has no stay point
# traj 3466 has no stay point
# traj 3480 has no stay point
# traj 3493 has no stay point
# traj 3562 has no stay point
# traj 3597 has no stay point
# traj 3618 has no stay point
# traj 3620 has no stay point
# traj 3675 has no stay point
# traj 3685 has no stay point
# traj 3686 has no stay point
# traj 3702 has no stay point
# traj 3710 has no stay point
# traj 3722 has no stay point
# traj 3726 has no stay point
# traj 3736 has no stay point
# traj 3764 has no stay point
# traj 3770 has no stay point
# traj 3774 has no stay point
# traj 3780 has no stay point
# traj 3784 has no stay point
# traj 3787 has no stay point
# traj 3791 has no stay point
# traj 3794 has no stay point
# traj 3795 has no stay point
# traj 3802 has no stay point
# traj 3805 has no stay point
# traj 3816 has no stay point
# traj 3832 has no stay point
# traj 3836 has no stay point
# traj 3843 has no stay point
# traj 3845 has no stay point
# traj 3846 has no stay point
# traj 3851 has no stay point
# traj 3852 has no stay point
# traj 3854 has no stay point
# traj 3862 has no stay point
# traj 3875 has no stay point
# traj 3948 has no stay point
# traj 3971 has no stay point
# traj 3982 has no stay point
# traj 3988 has no stay point
# traj 4013 has no stay point
# traj 4029 has no stay point
# traj 4042 has no stay point
# traj 4043 has no stay point
# traj 4064 has no stay point
# traj 4067 has no stay point
# traj 4069 has no stay point
# traj 4080 has no stay point
# traj 4082 has no stay point
# traj 4090 has no stay point
# traj 4116 has no stay point
# traj 4125 has no stay point
# traj 4144 has no stay point
# traj 4156 has no stay point
# traj 4159 has no stay point
# traj 4161 has no stay point
# traj 4166 has no stay point
# traj 4176 has no stay point
# traj 4178 has no stay point
# traj 4179 has no stay point
# traj 4188 has no stay point
# traj 4194 has no stay point
# traj 4208 has no stay point
# traj 4214 has no stay point
# traj 4218 has no stay point
# traj 4223 has no stay point
# traj 4226 has no stay point
# traj 4228 has no stay point
# traj 4230 has no stay point
# traj 4232 has no stay point
# traj 4235 has no stay point
# traj 4238 has no stay point
# traj 4241 has no stay point
# traj 4242 has no stay point
# traj 4250 has no stay point
# traj 4254 has no stay point
# traj 4255 has no stay point
# traj 4278 has no stay point
# traj 4280 has no stay point
# traj 4288 has no stay point
# traj 4296 has no stay point
# traj 4297 has no stay point
# traj 4299 has no stay point
# traj 4301 has no stay point
# traj 4302 has no stay point
# traj 4311 has no stay point
# traj 4313 has no stay point
# traj 4315 has no stay point
# traj 4321 has no stay point
# traj 4363 has no stay point
# traj 4365 has no stay point
# traj 4369 has no stay point
# traj 4372 has no stay point
# traj 4375 has no stay point
# traj 4377 has no stay point
# traj 4380 has no stay point
# traj 4383 has no stay point
# traj 4401 has no stay point
# traj 4421 has no stay point
# traj 4423 has no stay point
# traj 4425 has no stay point
# traj 4430 has no stay point
# traj 4432 has no stay point
# traj 4438 has no stay point
# traj 4440 has no stay point
# traj 4444 has no stay point
# traj 4446 has no stay point
# traj 4450 has no stay point
# traj 4453 has no stay point
# traj 4455 has no stay point
# traj 4457 has no stay point
# traj 4472 has no stay point
# traj 4479 has no stay point
# traj 4481 has no stay point
# traj 4486 has no stay point
# traj 4493 has no stay point
# traj 4495 has no stay point
# traj 4561 has no stay point
# traj 4585 has no stay point
# traj 4597 has no stay point
# traj 4602 has no stay point
# traj 4613 has no stay point
# traj 4616 has no stay point
# traj 4627 has no stay point
# traj 4645 has no stay point
# traj 4646 has no stay point
# traj 4663 has no stay point
# traj 4694 has no stay point
# traj 4702 has no stay point
# traj 4709 has no stay point
# traj 4713 has no stay point
# traj 4722 has no stay point
# traj 4750 has no stay point
# traj 4758 has no stay point
# traj 4763 has no stay point
# traj 4770 has no stay point
# traj 4776 has no stay point
# traj 4778 has no stay point
# traj 4780 has no stay point
# traj 4782 has no stay point
# traj 4803 has no stay point
# traj 4805 has no stay point
# traj 4825 has no stay point
# traj 4845 has no stay point
# traj 4880 has no stay point
# traj 4882 has no stay point
# traj 4883 has no stay point
# traj 4888 has no stay point
# traj 4895 has no stay point
# traj 4904 has no stay point
# traj 4946 has no stay point
# traj 4957 has no stay point
# traj 4969 has no stay point
# traj 4979 has no stay point
# traj 4984 has no stay point
# traj 4993 has no stay point
# traj 4998 has no stay point
# traj 5045 has no stay point
# traj 5046 has no stay point
# traj 5055 has no stay point
# traj 5056 has no stay point
# traj 5057 has no stay point
# traj 5062 has no stay point
# traj 5070 has no stay point
# traj 5075 has no stay point
# traj 5094 has no stay point
# traj 5098 has no stay point
# traj 5104 has no stay point
# traj 5108 has no stay point
# traj 5119 has no stay point
# traj 5125 has no stay point
# traj 5149 has no stay point
# traj 5182 has no stay point
# traj 5188 has no stay point
# traj 5191 has no stay point
# traj 5214 has no stay point
# traj 5225 has no stay point
# traj 5238 has no stay point
# traj 5257 has no stay point
# traj 5275 has no stay point
# traj 5285 has no stay point
# traj 5288 has no stay point
# traj 5289 has no stay point
# traj 5295 has no stay point
# traj 5306 has no stay point
# traj 5312 has no stay point
# traj 5341 has no stay point
# traj 5343 has no stay point
# traj 5350 has no stay point
# traj 5355 has no stay point
# traj 5360 has no stay point
# traj 5365 has no stay point
# traj 5366 has no stay point
# traj 5369 has no stay point
# traj 5373 has no stay point
# traj 5421 has no stay point
# traj 5437 has no stay point
# traj 5443 has no stay point
# traj 5469 has no stay point
# traj 5542 has no stay point
# traj 5569 has no stay point
# traj 5574 has no stay point
# traj 5576 has no stay point
# traj 5610 has no stay point
# traj 5613 has no stay point
# traj 5616 has no stay point
# traj 5618 has no stay point
# traj 5625 has no stay point
# traj 5652 has no stay point
# traj 5654 has no stay point
# traj 5656 has no stay point
# traj 5657 has no stay point
# traj 5661 has no stay point
# traj 5664 has no stay point
# traj 5668 has no stay point
# traj 5671 has no stay point
# traj 5697 has no stay point
# traj 5703 has no stay point
# traj 5708 has no stay point
# traj 5709 has no stay point
# traj 5737 has no stay point
# traj 5739 has no stay point
# traj 5767 has no stay point
# traj 5771 has no stay point
# traj 5779 has no stay point
# traj 5849 has no stay point
# traj 5875 has no stay point
# traj 5886 has no stay point
# traj 5892 has no stay point
# traj 5893 has no stay point
# traj 5895 has no stay point
# traj 5897 has no stay point
# traj 5921 has no stay point
# traj 5922 has no stay point
# traj 5928 has no stay point
# traj 5929 has no stay point
# traj 5943 has no stay point
# traj 5960 has no stay point
# traj 5991 has no stay point
# traj 6017 has no stay point
# traj 6020 has no stay point
# traj 6023 has no stay point
# traj 6039 has no stay point
# traj 6088 has no stay point
# traj 6156 has no stay point
# traj 6187 has no stay point
# traj 6189 has no stay point
# traj 6195 has no stay point
# traj 6203 has no stay point
# traj 6205 has no stay point
# traj 6206 has no stay point
# traj 6281 has no stay point
# traj 6286 has no stay point
# traj 6297 has no stay point
# traj 6304 has no stay point
# traj 6308 has no stay point
# traj 6340 has no stay point
# traj 6356 has no stay point
# traj 6363 has no stay point
# traj 6396 has no stay point
# traj 6399 has no stay point
# traj 6400 has no stay point
# traj 6404 has no stay point
# traj 6406 has no stay point
# traj 6426 has no stay point
# traj 6430 has no stay point
# traj 6439 has no stay point
# traj 6442 has no stay point
# traj 6445 has no stay point
# traj 6446 has no stay point
# traj 6450 has no stay point
# traj 6455 has no stay point
# traj 6456 has no stay point
# traj 6459 has no stay point
# traj 6466 has no stay point
# traj 6470 has no stay point
# traj 6494 has no stay point
# traj 6520 has no stay point
# traj 6572 has no stay point
# traj 6594 has no stay point
# traj 6653 has no stay point
# traj 6665 has no stay point
# traj 6670 has no stay point
# traj 6682 has no stay point
# traj 6685 has no stay point
# traj 6690 has no stay point
# traj 6694 has no stay point
# traj 6703 has no stay point
# traj 6704 has no stay point
# traj 6706 has no stay point
# traj 6709 has no stay point
# traj 6714 has no stay point
# traj 6717 has no stay point
# traj 6721 has no stay point
# traj 6725 has no stay point
# traj 6761 has no stay point
# traj 6767 has no stay point
# traj 6774 has no stay point
# traj 6777 has no stay point
# traj 6779 has no stay point
# traj 6803 has no stay point
# traj 6812 has no stay point
# traj 6838 has no stay point
# traj 6846 has no stay point
# traj 6850 has no stay point
# traj 6854 has no stay point
# traj 6893 has no stay point
# traj 6931 has no stay point
# traj 6933 has no stay point
# traj 6935 has no stay point
# traj 6942 has no stay point
# traj 6946 has no stay point
# traj 6947 has no stay point
# traj 6969 has no stay point
# traj 6971 has no stay point
# traj 6989 has no stay point
# traj 7000 has no stay point
# traj 7008 has no stay point
# traj 7030 has no stay point
# traj 7050 has no stay point
# traj 7053 has no stay point
# traj 7083 has no stay point
# traj 7099 has no stay point
# traj 7117 has no stay point
# traj 7118 has no stay point
# traj 7121 has no stay point
# traj 7122 has no stay point
# traj 7125 has no stay point
# traj 7158 has no stay point
# traj 7160 has no stay point
# traj 7165 has no stay point
# traj 7168 has no stay point
# traj 7174 has no stay point
# traj 7176 has no stay point
# traj 7182 has no stay point
# traj 7185 has no stay point
# traj 7189 has no stay point
# traj 7190 has no stay point
# traj 7193 has no stay point
# traj 7198 has no stay point
# traj 7199 has no stay point
# traj 7212 has no stay point
# traj 7213 has no stay point
# traj 7219 has no stay point
# traj 7220 has no stay point
# traj 7226 has no stay point
# traj 7251 has no stay point
# traj 7268 has no stay point
# traj 7270 has no stay point
# traj 7272 has no stay point
# traj 7274 has no stay point
# traj 7296 has no stay point
# traj 7298 has no stay point
# traj 7299 has no stay point
# traj 7301 has no stay point
# traj 7336 has no stay point
# traj 7340 has no stay point
# traj 7366 has no stay point
# traj 7383 has no stay point
# traj 7384 has no stay point
# traj 7387 has no stay point
# traj 7389 has no stay point
# traj 7391 has no stay point
# traj 7393 has no stay point
# traj 7399 has no stay point
# traj 7405 has no stay point
# traj 7411 has no stay point
# traj 7455 has no stay point
# traj 7480 has no stay point
# traj 7528 has no stay point
# traj 7551 has no stay point
# traj 7586 has no stay point
# traj 7603 has no stay point
# traj 7606 has no stay point
# traj 7607 has no stay point
# traj 7609 has no stay point
# traj 7610 has no stay point
# traj 7611 has no stay point
# traj 7612 has no stay point
# traj 7614 has no stay point
# traj 7617 has no stay point
# traj 7618 has no stay point
# traj 7619 has no stay point
# traj 7620 has no stay point
# traj 7623 has no stay point
# traj 7625 has no stay point
# traj 7634 has no stay point
# traj 7635 has no stay point
# traj 7637 has no stay point
# traj 7642 has no stay point
# traj 7643 has no stay point
# traj 7644 has no stay point
# traj 7650 has no stay point
# traj 7652 has no stay point
# traj 7653 has no stay point
# traj 7654 has no stay point
# traj 7655 has no stay point
# traj 7659 has no stay point
# traj 7661 has no stay point
# traj 7662 has no stay point
# traj 7663 has no stay point
# traj 7664 has no stay point
# traj 7668 has no stay point
# traj 7676 has no stay point
# traj 7679 has no stay point
# traj 7680 has no stay point
# traj 7697 has no stay point
# traj 7723 has no stay point
# traj 7736 has no stay point
# traj 7745 has no stay point
# traj 7757 has no stay point
# traj 7791 has no stay point
# traj 7794 has no stay point
# traj 7800 has no stay point
# traj 7801 has no stay point
# traj 7808 has no stay point
# traj 7818 has no stay point
# traj 7821 has no stay point
# traj 7835 has no stay point
# traj 7842 has no stay point
# traj 7844 has no stay point
# traj 7850 has no stay point
# traj 7855 has no stay point
# traj 7857 has no stay point
# traj 7859 has no stay point
# traj 7878 has no stay point
# traj 7885 has no stay point
# traj 7891 has no stay point
# traj 7894 has no stay point
# traj 7899 has no stay point
# traj 7903 has no stay point
# traj 7905 has no stay point
# traj 7907 has no stay point
# traj 7908 has no stay point
# traj 7909 has no stay point
# traj 7910 has no stay point
# traj 7915 has no stay point
# traj 7918 has no stay point
# traj 7921 has no stay point
# traj 7929 has no stay point
# traj 7932 has no stay point
# traj 7937 has no stay point
# traj 7939 has no stay point
# traj 7942 has no stay point
# traj 7952 has no stay point
# traj 7967 has no stay point
# traj 7969 has no stay point
# traj 7977 has no stay point
# traj 7979 has no stay point
# traj 8004 has no stay point
# traj 8005 has no stay point
# traj 8010 has no stay point
# traj 8012 has no stay point
# traj 8021 has no stay point
# traj 8042 has no stay point
# traj 8107 has no stay point
# traj 8119 has no stay point
# traj 8124 has no stay point
# traj 8126 has no stay point
# traj 8142 has no stay point
# traj 8154 has no stay point
# traj 8164 has no stay point
# traj 8192 has no stay point
# traj 8204 has no stay point
# traj 8206 has no stay point
# traj 8208 has no stay point
# traj 8225 has no stay point
# traj 8252 has no stay point
# traj 8273 has no stay point
# traj 8276 has no stay point
# traj 8281 has no stay point
# traj 8285 has no stay point
# traj 8296 has no stay point
# traj 8311 has no stay point
# traj 8319 has no stay point
# traj 8321 has no stay point
# traj 8332 has no stay point
# traj 8333 has no stay point
# traj 8340 has no stay point
# traj 8343 has no stay point
# traj 8345 has no stay point
# traj 8348 has no stay point
# traj 8349 has no stay point
# traj 8354 has no stay point
# traj 8360 has no stay point
# traj 8361 has no stay point
# traj 8364 has no stay point
# traj 8367 has no stay point
# traj 8371 has no stay point
# traj 8380 has no stay point
# traj 8384 has no stay point
# traj 8385 has no stay point
# traj 8387 has no stay point
# traj 8389 has no stay point
# traj 8398 has no stay point
# traj 8404 has no stay point
# traj 8407 has no stay point
# traj 8408 has no stay point
# traj 8410 has no stay point
# traj 8411 has no stay point
# traj 8415 has no stay point
# traj 8417 has no stay point
# traj 8418 has no stay point
# traj 8421 has no stay point
# traj 8422 has no stay point
# traj 8423 has no stay point
# traj 8427 has no stay point
# traj 8445 has no stay point
# traj 8476 has no stay point
# traj 8483 has no stay point
# traj 8508 has no stay point
# traj 8514 has no stay point
# traj 8515 has no stay point
# traj 8519 has no stay point
# traj 8520 has no stay point
# traj 8522 has no stay point
# traj 8526 has no stay point
# traj 8530 has no stay point
# traj 8539 has no stay point
# traj 8540 has no stay point
# traj 8546 has no stay point
# traj 8558 has no stay point
# traj 8570 has no stay point
# traj 8576 has no stay point
# traj 8606 has no stay point
# traj 8607 has no stay point
# traj 8608 has no stay point
# traj 8628 has no stay point
# traj 8629 has no stay point
# traj 8630 has no stay point
# traj 8632 has no stay point
# traj 8634 has no stay point
# traj 8638 has no stay point
# traj 8640 has no stay point
# traj 8643 has no stay point
# traj 8646 has no stay point
# traj 8658 has no stay point
# traj 8670 has no stay point
# traj 8701 has no stay point
# traj 8708 has no stay point
# traj 8709 has no stay point
# traj 8789 has no stay point
# traj 8817 has no stay point
# traj 8842 has no stay point
# traj 8849 has no stay point
# traj 8850 has no stay point
# traj 8852 has no stay point
# traj 8877 has no stay point
# traj 8889 has no stay point
# traj 8890 has no stay point
# traj 8897 has no stay point
# traj 8899 has no stay point
# traj 8902 has no stay point
# traj 8905 has no stay point
# traj 8908 has no stay point
# traj 8915 has no stay point
# traj 8945 has no stay point
# traj 8947 has no stay point
# traj 8951 has no stay point
# traj 8953 has no stay point
# traj 8957 has no stay point
# traj 8960 has no stay point
# traj 8961 has no stay point
# traj 8968 has no stay point
# traj 8973 has no stay point
# traj 8978 has no stay point
# traj 8984 has no stay point
# traj 8992 has no stay point
# traj 9008 has no stay point
# traj 9023 has no stay point
# traj 9032 has no stay point
# traj 9039 has no stay point
# traj 9048 has no stay point
# traj 9051 has no stay point
# traj 9067 has no stay point
# traj 9074 has no stay point
# traj 9079 has no stay point
# traj 9090 has no stay point
# traj 9092 has no stay point
# traj 9103 has no stay point
# traj 9118 has no stay point
# traj 9119 has no stay point
# traj 9130 has no stay point
# traj 9133 has no stay point
# traj 9137 has no stay point
# traj 9140 has no stay point
# traj 9143 has no stay point
# traj 9149 has no stay point
# traj 9151 has no stay point
# traj 9153 has no stay point
# traj 9168 has no stay point
# traj 9176 has no stay point
# traj 9177 has no stay point
# traj 9225 has no stay point
# traj 9244 has no stay point
# traj 9247 has no stay point
# traj 9256 has no stay point
# traj 9262 has no stay point
# traj 9264 has no stay point
# traj 9268 has no stay point
# traj 9273 has no stay point
# traj 9275 has no stay point
# traj 9278 has no stay point
# traj 9294 has no stay point
# traj 9297 has no stay point
# traj 9302 has no stay point
# traj 9312 has no stay point
# traj 9315 has no stay point
# traj 9339 has no stay point
# traj 9343 has no stay point
# traj 9347 has no stay point
# traj 9383 has no stay point
# traj 9387 has no stay point
# traj 9389 has no stay point
# traj 9395 has no stay point
# traj 9400 has no stay point
# traj 9402 has no stay point
# traj 9405 has no stay point
# traj 9408 has no stay point
# 8487 files contain stay points

# %%
import transbigdata
df = pd.read_csv('rome_final.csv', usecols=["tag_new", "latitude", "longitude", "timestamp"],float_precision='high')
data=transbigdata.traj_densify(df, col=["tag_new", "timestamp", "longitude", "latitude"], timegap=15)
data.to_csv('den.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_57592\3513702600.py in <module>
#       1 import transbigdata
# ----> 2 data=transbigdata.traj_densify(df, col=["tag_new", "timestamp", "longitude", "latitude"], timegap=15)
#       3 data.to_csv('den.csv')
#
# D:\conda\envs\pygeo\lib\site-packages\transbigdata\traj.py in traj_densify(data, col, timegap)
#      74     timedata['tmp'] = 1
#      75     minmaxtime['tmp'] = 1
# ---> 76     minmaxtime = pd.merge(minmaxtime, timedata)
#      77     minmaxtime = minmaxtime[(minmaxtime['mintime'] <= minmaxtime[Time]) & (
#      78         minmaxtime['maxtime'] >= minmaxtime[Time])]
#
# D:\conda\envs\pygeo\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     119         validate=validate,
#     120     )
# --> 121     return op.get_result()
#     122
#     123
#
# D:\conda\envs\pygeo\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     713             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     714
# --> 715         join_index, left_indexer, right_indexer = self._get_join_info()
#     716
#     717         llabels, rlabels = _items_overlap_with_suffix(
#
# D:\conda\envs\pygeo\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     998                     right_indexer = np.array([-1] * len(join_index), dtype=np.intp)
#     999             else:
# -> 1000                 join_index = Index(np.arange(len(left_indexer)))
#    1001
#    1002         if len(join_index) == 0:
#
# D:\conda\envs\pygeo\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     467
#     468             klass = cls._dtype_to_subclass(arr.dtype)
# --> 469             arr = klass._ensure_array(arr, dtype, copy)
#     470             disallow_kwargs(kwargs)
#     471             return klass._simple_new(arr, name)
#
# D:\conda\envs\pygeo\lib\site-packages\pandas\core\indexes\numeric.py in _ensure_array(cls, data, dtype, copy)
#     162
#     163         if copy or not is_dtype_equal(data.dtype, dtype):
# --> 164             subarr = np.array(data, dtype=dtype, copy=copy)
#     165             cls._assert_safe_casting(data, subarr)
#     166         else:
#
# MemoryError: Unable to allocate 12.1 GiB for an array with shape (1627603200,) and data type int64
